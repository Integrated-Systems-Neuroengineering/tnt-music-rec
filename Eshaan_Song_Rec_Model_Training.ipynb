# %%
import pandas as pd

# %%
df = pd.read_csv("spotify_millsongdata.csv")

# %%
df.head(5)
# Out:
#   artist                   song                                        link  \
# 0   ABBA  Ahe's My Kind Of Girl  /a/abba/ahes+my+kind+of+girl_20598417.html
# 1   ABBA       Andante, Andante       /a/abba/andante+andante_20002708.html
# 2   ABBA         As Good As New        /a/abba/as+good+as+new_20003033.html
# 3   ABBA                   Bang                  /a/abba/bang_20598415.html
# 4   ABBA       Bang-A-Boomerang      /a/abba/bang+a+boomerang_20002668.html
#
#                                                 text
# 0  Look at her face, it's a wonderful face  \r\nA...
# 1  Take it easy with me, please  \r\nTouch me gen...
# 2  I'll never know why I had to go  \r\nWhy I had...
# 3  Making somebody happy is a question of give an...
# 4  Making somebody happy is a question of give an...

# %%
df.shape
# Out:
# (57650, 4)

# %%
df = df.drop('link', axis=1).reset_index(drop=True)

# %%
df.head(10)
# Out:
#   artist                   song  \
# 0   ABBA  Ahe's My Kind Of Girl
# 1   ABBA       Andante, Andante
# 2   ABBA         As Good As New
# 3   ABBA                   Bang
# 4   ABBA       Bang-A-Boomerang
# 5   ABBA     Burning My Bridges
# 6   ABBA              Cassandra
# 7   ABBA             Chiquitita
# 8   ABBA            Crazy World
# 9   ABBA        Crying Over You
#
#                                                 text
# 0  Look at her face, it's a wonderful face  \r\nA...
# 1  Take it easy with me, please  \r\nTouch me gen...
# 2  I'll never know why I had to go  \r\nWhy I had...
# 3  Making somebody happy is a question of give an...
# 4  Making somebody happy is a question of give an...
# 5  Well, you hoot and you holler and you make me ...
# 6  Down in the street they're all singing and sho...
# 7  Chiquitita, tell me what's wrong  \r\nYou're e...
# 8  I was out with the morning sun  \r\nCouldn't s...
# 9  I'm waitin' for you baby  \r\nI'm sitting all ...

# %%
df.sample(5000)
# Out:
#                  artist                       song  \
# 22548      Ziggy Marley                 Live It Up
# 53772  Townes Van Zandt              Colorado Girl
# 9274       Jimi Hendrix  Here He Comes (Lover Man)
# 38379        John Waite           Going To The Top
# 47640    Paul McCartney              It's Not True
# ...                 ...                        ...
# 21567     Willie Nelson         Each Night At Nine
# 53023        Thin Lizzy        Boogie Woogie Dance
# 11148      Lana Del Rey                Cruel World
# 49088       Proclaimers          It Broke My Heart
# 29049       Dean Martin       Dreamer With A Penny
#
#                                                     text
# 22548  If life means what it means to me  \r\nHappine...
# 53772  I'm goin' out to Denver  \r\nSee if I can't fi...
# 9274   Jimi:  \r\n"Ok, here we go. I'm gonna try it w...
# 38379  Saw you standing in the darkness  \r\nWith you...
# 47640  Some People say she's a bad girl  \r\nSome peo...
# ...                                                  ...
# 21567  A thousand miles, dear  \r\nA thousand more ac...
# 53023  In France, they've got a dance  \r\nA feel rea...
# 11148  [Intro]  \r\nMy body and my mind with you  \r\...
# 49088  Saw a man who was fifty-one  \r\nHe bad marrie...
# 29049  I'd rather be a dreamer with a penny  \r\nThan...
#
# [5000 rows x 3 columns]

# %%
df = df.sample(5000)

# %% [markdown]
# **Text Cleaning / Text Preprocessing**

# %%
df['text'] = df['text'].str.lower().replace(r'^\w\s', '').replace(r'\n', ' ', regex = True)

# %%
df.tail(5)
# Out:
#               artist                           song  \
# 56915         Xscape            Keep It On The Real
# 45864    Nina Simone                   I Am Blessed
# 26893     Carpenters   It's Going To Take Some Time
# 11349  Lenny Kravitz  Can't Stop Thinkin' 'Bout You
# 17244  Reba Mcentire                    I'm A Woman
#
#                                                     text
# 56915  no no,  \r tell me, tell me.  \r   \r keep it ...
# 45864  i who never had much i now have a treasure  \r...
# 26893  it's gonna take some time this time  \r to get...
# 11349  it get's old living in this jungle  \r and i'v...
# 17244  well i can wash out forty four pairs of socks ...

# %%
import nltk
from nltk.stem.porter import PorterStemmer

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
stemmer = PorterStemmer()

# %%
def token(txt):
  token = nltk.word_tokenize(txt)
  a = [stemmer.stem(w) for w in token]
  return " ".join(a)

# %%
token("you are beautiful, beauty")
# Out:
# 'you are beauti , beauti'

# %%
df['text'].apply(lambda x: token(x))
# Out:
# 49783    thi is the place sit down , you 're safe now y...
# 44402    she said she 'd come , she did n't i 'm the on...
# 16757    thi is a radio messag to my babi , and i 'm co...
# 44446    walk home with you last night you said the wor...
# 34123    i believ for everi drop of rain that fall a fl...
#                                ...
# 56915    no no , tell me , tell me . keep it on the rea...
# 45864    i who never had much i now have a treasur a lo...
# 26893    it 's gon na take some time thi time to get my...
# 11349    it get 's old live in thi jungl and i 've lost...
# 17244    well i can wash out forti four pair of sock an...
# Name: text, Length: 5000, dtype: object

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
tfid = TfidfVectorizer(analyzer='word', stop_words='english')

# %%
matrix=tfid.fit_transform(df['text'])

# %%
similar = cosine_similarity(matrix)

# %%
similar[0]
# Out:
# array([1.        , 0.00399333, 0.04676045, ..., 0.07725459, 0.00561884,
#        0.00803073])

# %%
df[df['song']=='Keep It On The Real'].index[0]
# Out:
# 56915

# %% [markdown]
# ## Recommender Function

# %%
def recommender(song_name):
  idx = df[df['song']==song_name].index[0]
  distance = sorted(list(enumerate(similar[idx])), reverse=True, key = lambda x:x[1])
  song = []
  for s_id in distance[1:5]:
    song.append(df.iloc[s_id[0]].song)
  return song

# %%
recommender("Keep It On The Real")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-42-acea8c42eb18> in <cell line: 1>()
# ----> 1 recommender("Keep It On The Real")
#
# <ipython-input-41-4dbbd4c1afb8> in recommender(song_name)
#       1 def recommender(song_name):
#       2   idx = df[df['song']==song_name].index[0]
# ----> 3   distance = sorted(list(enumerate(similar[idx])), reverse=True, key = lambda x:x[1])
#       4   song = []
#       5   for s_id in distance[1:5]:
#
# IndexError: index 56915 is out of bounds for axis 0 with size 5000

# %% [markdown]
# ended at 31:50
